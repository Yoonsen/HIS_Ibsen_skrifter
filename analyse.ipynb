# %%
import pandas as pd
from collections import Counter
import ast

def count_numbers(df, column_name):
    # Flatten all lists in the column and count occurrences
    all_numbers = []
    
    for cell in df[column_name]:
        # If the cell is a string (common when reading from files), evaluate it
        if isinstance(cell, str):
            cell = ast.literal_eval(cell)
        # Add all numbers from the cell to our list
        all_numbers.extend(cell)
    
    # Count occurrences of each number
    counts = Counter(all_numbers)
    
    # Create a dictionary with all numbers 1-16, even if they don't appear
    full_counts = {i: counts.get(i, 0) for i in range(1, 17)}
    
    return pd.DataFrame({
        'number': list(full_counts.keys()),
        'count': list(full_counts.values())
    })

# %%
df = pd.read_excel("Rosmersholm_refs.xlsx", index_col=0)

# %%
df
# Out:
#               Taler                                             Dialog  \
# 0               act                                                  0
# 1     MADAM HELSETH  Det er vel bedst, jeg [6] begynder så småt at ...
# 2      REBEKKA WEST   Ja, gør De det. Pastoren [1] må vel snart komme.
# 3     MADAM HELSETH   Trækker det ikke svært, dér frøkenen [2] sidder?
# 4           REBEKKA                 Jo, lidt. Vil De [6] kanske lukke.
# ...             ...                                                ...
# 1375         ROSMER  Vi [1, 2] to følger hinanden, Rebekka [2]. Jeg...
# 1376        REBEKKA                      Det tror jeg [2] næsten også.
# 1377         ROSMER                         For nu er vi [1, 2] to et.
# 1378        REBEKKA  Ja. Nu er vi [1, 2] et. Kom! Så går vi [1, 2] ...
# 1379  MADAM HELSETH  Frøken [2], – nu er vognen – må jeg [6] sige –...
#
#                                              Referanser
# 0                                                    []
# 1                                               ['[6]']
# 2                                               ['[1]']
# 3                                               ['[2]']
# 4                                               ['[6]']
# ...                                                 ...
# 1375      ['[1, 2]', '[2]', '[1]', '[2]', '[2]', '[1]']
# 1376                                            ['[2]']
# 1377                                         ['[1, 2]']
# 1378                               ['[1, 2]', '[1, 2]']
# 1379  ['[2]', '[6]', '[6]', '[1, 2]', '[1, 2]', '[1,...
#
# [1380 rows x 3 columns]

# %%
from collections import Counter

def count_patterns(data):
    # Flatten the outer lists and count each pattern
    all_patterns = []
    for row in data:
        # If it's a string, evaluate it to a list
        if isinstance(row, str):
            row = eval(row)
        # Add each pattern from the row
        all_patterns.extend(row)
    
    counts = Counter(all_patterns)
    
    # Create a DataFrame with the results
    result = pd.DataFrame({
        'pattern': list(counts.keys()),
        'count': list(counts.values())
    })
    
    # Sort for readability
    result = result.sort_values('pattern')
    
    return result

# %%
len(df)/6
# Out:
# 230.0

# %%
# Example usage:
# Assuming your list is in a DataFrame column
patterns = df['Referanser']
result = count_patterns(patterns)

# %%
patterns
# Out:
# 0                                                      []
# 1                                                 ['[6]']
# 2                                                 ['[1]']
# 3                                                 ['[2]']
# 4                                                 ['[6]']
#                               ...
# 1375        ['[1, 2]', '[2]', '[1]', '[2]', '[2]', '[1]']
# 1376                                              ['[2]']
# 1377                                           ['[1, 2]']
# 1378                                 ['[1, 2]', '[1, 2]']
# 1379    ['[2]', '[6]', '[6]', '[1, 2]', '[1, 2]', '[1,...
# Name: Referanser, Length: 1380, dtype: object

# %%
patts = {}
res = {}
tot_n = len(df['Referanser'])
step = int(tot_n/6)
for i in range(0, tot_n, step):
    res[i] = count_patterns(df.iloc[i:i+step]["Referanser"])
    res[i].columns = ["pattern", f"count-{i}"]
#    result[i] = res[i].set_index("pattern").T

# %%
df_tot = pd.concat([res[i].set_index("pattern").T for i in res])

# %%
df_tot[['[1, 2]','[1]','[2]','[3]','[4]','[5]','[6]']].style.background_gradient(axis=1)
# Out:
# <style type="text/css">
# #T_03791_row0_col0 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_03791_row0_col1 {
#   background-color: #0c74b2;
#   color: #f1f1f1;
# }
# #T_03791_row0_col2 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_03791_row0_col3, #T_03791_row1_col1, #T_03791_row2_col1, #T_03791_row3_col1, #T_03791_row4_col2, #T_03791_row5_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_03791_row0_col4, #T_03791_row2_col2, #T_03791_row2_col6 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_03791_row0_col5, #T_03791_row1_col6, #T_03791_row2_col4, #T_03791_row3_col3, #T_03791_row4_col0, #T_03791_row4_col5, #T_03791_row5_col6 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_03791_row0_col6 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_03791_row1_col0, #T_03791_row2_col0, #T_03791_row5_col3 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_03791_row1_col2 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_03791_row1_col3 {
#   background-color: #4295c3;
#   color: #f1f1f1;
# }
# #T_03791_row1_col4 {
#   background-color: #529bc7;
#   color: #f1f1f1;
# }
# #T_03791_row1_col5 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_03791_row2_col3, #T_03791_row4_col1 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_03791_row2_col5 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
# }
# #T_03791_row3_col0 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_03791_row3_col2 {
#   background-color: #5c9fc9;
#   color: #f1f1f1;
# }
# #T_03791_row3_col4 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_03791_row3_col5 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_03791_row3_col6, #T_03791_row5_col4 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_03791_row4_col3 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_03791_row4_col4 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_03791_row4_col6 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_03791_row5_col0 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_03791_row5_col1 {
#   background-color: #034c78;
#   color: #f1f1f1;
# }
# #T_03791_row5_col5 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# </style>
# <table id="T_03791">
#   <thead>
#     <tr>
#       <th class="index_name level0" >pattern</th>
#       <th id="T_03791_level0_col0" class="col_heading level0 col0" >[1, 2]</th>
#       <th id="T_03791_level0_col1" class="col_heading level0 col1" >[1]</th>
#       <th id="T_03791_level0_col2" class="col_heading level0 col2" >[2]</th>
#       <th id="T_03791_level0_col3" class="col_heading level0 col3" >[3]</th>
#       <th id="T_03791_level0_col4" class="col_heading level0 col4" >[4]</th>
#       <th id="T_03791_level0_col5" class="col_heading level0 col5" >[5]</th>
#       <th id="T_03791_level0_col6" class="col_heading level0 col6" >[6]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_03791_level0_row0" class="row_heading level0 row0" >count-0</th>
#       <td id="T_03791_row0_col0" class="data row0 col0" >22</td>
#       <td id="T_03791_row0_col1" class="data row0 col1" >124</td>
#       <td id="T_03791_row0_col2" class="data row0 col2" >78</td>
#       <td id="T_03791_row0_col3" class="data row0 col3" >167</td>
#       <td id="T_03791_row0_col4" class="data row0 col4" >41</td>
#       <td id="T_03791_row0_col5" class="data row0 col5" >7</td>
#       <td id="T_03791_row0_col6" class="data row0 col6" >19</td>
#     </tr>
#     <tr>
#       <th id="T_03791_level0_row1" class="row_heading level0 row1" >count-230</th>
#       <td id="T_03791_row1_col0" class="data row1 col0" >7</td>
#       <td id="T_03791_row1_col1" class="data row1 col1" >199</td>
#       <td id="T_03791_row1_col2" class="data row1 col2" >69</td>
#       <td id="T_03791_row1_col3" class="data row1 col3" >121</td>
#       <td id="T_03791_row1_col4" class="data row1 col4" >115</td>
#       <td id="T_03791_row1_col5" class="data row1 col5" >14</td>
#       <td id="T_03791_row1_col6" class="data row1 col6" >5</td>
#     </tr>
#     <tr>
#       <th id="T_03791_level0_row2" class="row_heading level0 row2" >count-460</th>
#       <td id="T_03791_row2_col0" class="data row2 col0" >11</td>
#       <td id="T_03791_row2_col1" class="data row2 col1" >225</td>
#       <td id="T_03791_row2_col2" class="data row2 col2" >55</td>
#       <td id="T_03791_row2_col3" class="data row2 col3" >82</td>
#       <td id="T_03791_row2_col4" class="data row2 col4" >9</td>
#       <td id="T_03791_row2_col5" class="data row2 col5" >108</td>
#       <td id="T_03791_row2_col6" class="data row2 col6" >54</td>
#     </tr>
#     <tr>
#       <th id="T_03791_level0_row3" class="row_heading level0 row3" >count-690</th>
#       <td id="T_03791_row3_col0" class="data row3 col0" >25</td>
#       <td id="T_03791_row3_col1" class="data row3 col1" >191</td>
#       <td id="T_03791_row3_col2" class="data row3 col2" >114</td>
#       <td id="T_03791_row3_col3" class="data row3 col3" >20</td>
#       <td id="T_03791_row3_col4" class="data row3 col4" >21</td>
#       <td id="T_03791_row3_col5" class="data row3 col5" >32</td>
#       <td id="T_03791_row3_col6" class="data row3 col6" >52</td>
#     </tr>
#     <tr>
#       <th id="T_03791_level0_row4" class="row_heading level0 row4" >count-920</th>
#       <td id="T_03791_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_03791_row4_col1" class="data row4 col1" >88</td>
#       <td id="T_03791_row4_col2" class="data row4 col2" >252</td>
#       <td id="T_03791_row4_col3" class="data row4 col3" >82</td>
#       <td id="T_03791_row4_col4" class="data row4 col4" >18</td>
#       <td id="T_03791_row4_col5" class="data row4 col5" >5</td>
#       <td id="T_03791_row4_col6" class="data row4 col6" >28</td>
#     </tr>
#     <tr>
#       <th id="T_03791_level0_row5" class="row_heading level0 row5" >count-1150</th>
#       <td id="T_03791_row5_col0" class="data row5 col0" >27</td>
#       <td id="T_03791_row5_col1" class="data row5 col1" >225</td>
#       <td id="T_03791_row5_col2" class="data row5 col2" >243</td>
#       <td id="T_03791_row5_col3" class="data row5 col3" >4</td>
#       <td id="T_03791_row5_col4" class="data row5 col4" >47</td>
#       <td id="T_03791_row5_col5" class="data row5 col5" >8</td>
#       <td id="T_03791_row5_col6" class="data row5 col6" >2</td>
#     </tr>
#   </tbody>
# </table>

# %%
result.set_index("pattern").T
# Out:
# pattern  [1, 2, 3]  [1, 2, 5]  [1, 2, 6]  [1, 2]  [1, 3, 5]  [1, 3]  [1, 4]  \
# 2                3          1          2      97          1      29       4
#
# pattern  [1, 5]  [10]  [11]  ...  [4, 5]  [4]  [5, 2, 8]  [5]  [6, 2]  [6]  \
# 2             2     6    13  ...       2  251          2  174       2  160
#
# pattern  [7]  [8]  [9]  [Uidentificeret]
# 2          1   14    1                 6
#
# [1 rows x 37 columns]

# %%
result.to_excel("Counts.xlsx")
