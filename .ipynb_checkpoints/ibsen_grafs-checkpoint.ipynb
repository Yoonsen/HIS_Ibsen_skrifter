# %%
import json
import networkx as nx
from ibsen_networks import (
    load_parsed,
    build_speech_network_and_transitions,
    build_cooccurrence_network,
    export_ibsen_networks,
)

all_plays = load_parsed("ibsen_parsed.json")

rosmer = all_plays[2]  # eller filtrere på title
G_speech, trans = build_speech_network_and_transitions(rosmer)
G_co = build_cooccurrence_network(rosmer)

# %%
# Out:
# {'title': 'Rosmersholm_1886',
#  'file': 'plays/Rosmersholm_1886.xml',
#  'acts': [{'act_n': '1',
#    'scenes': [{'scene_n': '1',
#      'speakers_in_scene': ['JOHANNES  ROSMER ,  ejer af  Rosmersholm, forhenvÃ¦rende  sogneprest',
#       'MADAM  HELSETH ,  \n                         husholderske pÃ¥ Rosmersholm',
#       'REBEKKA  WEST ,  \n                         i huset hos Rosmer',
#       'REKTOR  KROLL ,  Rosmers svoger',
#       'ULRIK  BRENDEL'],
#      'speeches': [{'speaker': 'MADAM  HELSETH ,  \n                         husholderske pÃ¥ Rosmersholm',
#        'text': 'MADAM HELSETH\n                    \n                    \n                        Det er vel bedst, jeg begynder sÃ¥ smÃ¥t at dÃ¦kke kveldsbordet, frÃ¸ken?',
#        'length': 24},
#       {'speaker': 'REBEKKA  WEST ,  \n                         i huset hos Rosmer',
#        'text': 'REBEKKA WEST\n                    \n                    Ja, gÃ¸r De det. Pastoren mÃ¥ vel snart komme.',
# ...
